# 81251  116.683726  122.313204  121.033777
#
# [81252 rows x 26 columns]

# %%
# Calculate the number of rows to modify (30% of the training set)
rows_to_modify1 = int(0.3 * len(train_set))

# Identify the indices of the rows to modify (select from the beginning)
indices_to_modify1 = train_set.index[:rows_to_modify1]

# Columns to multiply by 0.3
columns_to_multiply = [f'hour_{i}' for i in range(24)]

train_set.loc[indices_to_modify1, columns_to_multiply] *= 0.2

# %%
train_set['Y'] = 0
train_set.loc[indices_to_modify1, 'Y'] = 1
# Out:
# C:\Users\2003n\AppData\Local\Temp\ipykernel_33212\3028245570.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set['Y'] = 0

# %%
train_set['Y'].value_counts()
# Out:
# Y
# 0    56877
# 1    24375
# Name: count, dtype: int64

# %%
# Calculate the number of rows to modify (30% of the training set)
rows_to_modify1 = int(0.3 * len(val_set))

# Identify the indices of the rows to modify (select from the beginning)
indices_to_modify1 = val_set.index[:rows_to_modify1]

# Columns to multiply by 0.3
columns_to_multiply = [f'hour_{i}' for i in range(24)]

val_set.loc[indices_to_modify1, columns_to_multiply] *= 0.2

# %%
val_set['Y'] = 0
val_set.loc[indices_to_modify1, 'Y'] = 1
# Out:
# C:\Users\2003n\AppData\Local\Temp\ipykernel_33212\563264050.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_set['Y'] = 0

# %%
val_set['Y'].value_counts()
# Out:
# Y
# 0    18959
# 1     8125
# Name: count, dtype: int64

# %%
# Calculate the number of rows to modify (30% of the training set)
rows_to_modify1 = int(0.3 * len(test_set))

# Identify the indices of the rows to modify (select from the beginning)
indices_to_modify1 = test_set.index[:rows_to_modify1]

# Columns to multiply by 0.3
columns_to_multiply = [f'hour_{i}' for i in range(24)]

test_set.loc[indices_to_modify1, columns_to_multiply] *= 0.2

# %%
test_set['Y'] = 0
test_set.loc[indices_to_modify1, 'Y'] = 1
# Out:
# C:\Users\2003n\AppData\Local\Temp\ipykernel_33212\1629470938.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_set['Y'] = 0

# %%
test_set['Y'].value_counts()
# Out:
# Y
# 0    18959
# 1     8125
# Name: count, dtype: int64

# %%
# row1=int(0.3*len(train_set))
# train_set.iloc[:row1,:24]=((train_set.iloc[:row1,:24])*0.3)
# train_set['Y'].iloc[:row1]=1
# train_set

# %%
# row2=int(0.3*len(test_set))
# test_set.iloc[row2:,:24]=((test_set.iloc[row2:,:24])*0.3)
# test_set['Y'].iloc[row2:]=1
# test_set

# %%
# train_set.shape
# val_set.shape
test_set.shape
# Out:
# (27084, 27)

# %%
train_set
# Out:
#        UserID        days      hour_0      hour_1      hour_2      hour_3  \
# 0      MT_001  2012-01-01    0.634518    0.824873    0.951777    0.888325
# 1      MT_001  2012-01-02    0.761421    0.761421    0.824873    0.761421
# 2      MT_001  2012-01-03    0.824873    0.824873    0.761421    0.761421
# 3      MT_001  2012-01-04    0.888325    1.015228    0.951777    0.888325
# 4      MT_001  2012-01-05    1.522843    2.855330    1.269036    3.553299
# ...       ...         ...         ...         ...         ...         ...
# 81247  MT_227  2012-12-27  167.349028  167.093142  162.998976  147.901740
# 81248  MT_227  2012-12-28  143.039918  144.831116  143.295803  133.572160
# 81249  MT_227  2012-12-29  151.228250  150.204708  152.763562  140.736950
# 81250  MT_227  2012-12-30  145.598772  145.342886  147.901740  136.642784
# 81251  MT_227  2012-12-31  122.313204  111.054248  112.077789  103.121801
#
#            hour_4      hour_5      hour_6      hour_7  ...     hour_15  \
# 0        0.951777    0.888325    0.888325    0.888325  ...    2.918782
# 1        0.824873    0.761421    0.634518    0.634518  ...    3.236041
# 2        0.697970    0.697970    0.634518    0.634518  ...    3.426396
# 3        0.951777    0.761421    0.888325    0.824873  ...    2.157360
# 4        3.616751    3.489848    2.728426    2.664975  ...    1.522843
# ...           ...         ...         ...         ...  ...         ...
# 81247  147.901740  178.863869  238.485159  278.915046  ...  305.271238
# 81248  139.457523  172.722620  237.205732  281.218014  ...  303.735926
# 81249  151.740020  194.216991  218.270215  262.794268  ...  314.994882
# 81250  143.295803  172.722620  218.781986  258.955988  ...  340.839304
# 81251  109.263050  139.201638  197.799386  243.602866  ...  340.327533
#
#           hour_16     hour_17     hour_18     hour_19     hour_20     hour_21  \
# 0        0.507614    1.522843    3.616751    1.015228    0.888325    3.616751
# 1        4.505076    2.474619    2.411168    0.761421    1.332487    2.982234
# 2        5.012690    1.078680    3.236041    2.220812    1.332487    3.616751
# 3        2.347716    4.949239    3.870558    1.903553    1.205584    3.045685
# 4        3.172589    3.172589    1.522843    2.982234    3.616751    3.743655
# ...           ...         ...         ...         ...         ...         ...
# 81247  323.950870  313.971341  311.412487  287.615148  275.076766  250.255885
# 81248  328.556807  318.577277  309.621290  301.944729  298.618219  253.070624
# 81249  324.206755  332.906858  325.486182  302.200614  280.962129  255.629478
# 81250  344.421699  332.906858  319.600819  317.809621  292.732856  268.423746
# 81251  339.303992  336.745138  290.174002  209.314227  133.316274  116.683726
#
#           hour_22     hour_23  Y
# 0        2.855330    2.220812  1
# 1        0.824873    2.728426  1
# 2        2.728426    2.728426  1
# 3        2.601523    2.157360  1
# 4        3.807107    3.236041  1
# ...           ...         ... ..
# 81247  240.788127  194.472876  0
# 81248  240.276356  199.846469  0
# 81249  248.720573  201.381781  0
# 81250  257.420676  196.519959  0
# 81251  122.313204  121.033777  0
#
# [81252 rows x 27 columns]

# %%
# yha issue ho raha hoga

# %%
x_train=train_set.iloc[:,2:26]
y_train=train_set['Y'].iloc[:]

x_val=val_set.iloc[:,2:26]
y_val=val_set['Y'].iloc[:]

x_test=test_set.iloc[:,2:26]
y_test=test_set['Y'].iloc[:]

# %%
print (x_train.shape)
print (y_train.shape)
print (x_val.shape)
print (y_val.shape)
print (x_test.shape)
print (y_test.shape)
# Out:
# (81252, 24)
# (81252,)
# (27084, 24)
# (27084,)
# (27084, 24)
# (27084,)

# %%
# from sklearn.preprocessing import StandardScaler

# # Initialize scaler
# scaler = StandardScaler()

# # Fit only on training data
# scaler.fit(x_train)

# # Transform train, validation, and test sets
# x_train_scaled = scaler.transform(x_train)
# x_val_scaled   = scaler.transform(x_val)
# x_test_scaled  = scaler.transform(x_test)

# %% [markdown]
# ## DL

# %% [markdown]
# ## FFNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from sklearn.metrics import confusion_matrix,classification_report
from tensorflow.keras.regularizers import l2

# %%
input_dim = x_train.shape[1]#mtlb ki hum column wise data feed karana chahte h kyunki x_train.shape= axis=0 and axis=1 dega but hume axis=1 chiye to hum 1 likhenge


model = Sequential([
    Dense(64, activation='relu', input_shape=(input_dim,), kernel_regularizer=l2(0.001)),
    Dropout(0.3),  # Dropout after first layer
    BatchNormalization(),
    
    Dense(64, activation='relu'),
    Dropout(0.1),  # Dropout after second layer
    BatchNormalization(),
    
    Dense(32, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.3),  # Dropout after third layer
    
    Dense(32, activation='relu'),
    Dropout(0.2),  # Optional: dropout after fourth layer

    Dense(16, activation='relu', kernel_regularizer=l2(0.001)),
    Dropout(0.1),  # Optional: dropout after fourth layer
    
    Dense(1, activation='sigmoid')  # Output layer for binary classification
])
# Out:
# C:\Users\2003n\anaconda3\envs\tf_env\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer=Adam(learning_rate=0.0005),
              loss='binary_crossentropy',# also called objective/cost function
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
                    epochs=25,
                    batch_size=32,
                    validation_data=(x_val, y_val),
                    shuffle=True,
                    verbose=1)
# Out:
# Epoch 1/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 27s 8ms/step - accuracy: 0.8281 - loss: 0.4291 - val_accuracy: 0.7052 - val_loss: 1.2523
# Epoch 2/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9229 - loss: 0.2617 - val_accuracy: 0.6995 - val_loss: 1.2975
# Epoch 3/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9239 - loss: 0.2365 - val_accuracy: 0.6993 - val_loss: 1.3719
# Epoch 4/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9275 - loss: 0.2226 - val_accuracy: 0.7147 - val_loss: 0.8492
# Epoch 5/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.9255 - loss: 0.2179 - val_accuracy: 0.6990 - val_loss: 1.2763
# Epoch 6/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.9242 - loss: 0.2235 - val_accuracy: 0.7054 - val_loss: 1.1983
# Epoch 7/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9249 - loss: 0.2154 - val_accuracy: 0.6987 - val_loss: 1.4452
# Epoch 8/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9279 - loss: 0.2062 - val_accuracy: 0.7132 - val_loss: 1.1266
# Epoch 9/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 17s 7ms/step - accuracy: 0.9274 - loss: 0.2043 - val_accuracy: 0.7256 - val_loss: 0.8805
# Epoch 10/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 17s 7ms/step - accuracy: 0.9299 - loss: 0.1975 - val_accuracy: 0.7068 - val_loss: 1.3648
# Epoch 11/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.9288 - loss: 0.1975 - val_accuracy: 0.7738 - val_loss: 0.7692
# Epoch 12/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.9313 - loss: 0.1952 - val_accuracy: 0.7113 - val_loss: 0.9384
# Epoch 13/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.9272 - loss: 0.1994 - val_accuracy: 0.7254 - val_loss: 0.7319
# Epoch 14/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - accuracy: 0.9291 - loss: 0.1965 - val_accuracy: 0.7713 - val_loss: 0.6773
# Epoch 15/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9301 - loss: 0.1937 - val_accuracy: 0.7165 - val_loss: 1.1022
# Epoch 16/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9282 - loss: 0.1989 - val_accuracy: 0.7102 - val_loss: 1.4453
# Epoch 17/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.9280 - loss: 0.2002 - val_accuracy: 0.7384 - val_loss: 1.0451
# Epoch 18/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.9277 - loss: 0.1962 - val_accuracy: 0.7539 - val_loss: 0.8281
# Epoch 19/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.9260 - loss: 0.2013 - val_accuracy: 0.7384 - val_loss: 1.0429
# Epoch 20/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.9244 - loss: 0.2020 - val_accuracy: 0.7767 - val_loss: 0.6442
# Epoch 21/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - accuracy: 0.9247 - loss: 0.2008 - val_accuracy: 0.7001 - val_loss: 1.6348
# Epoch 22/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9252 - loss: 0.2013 - val_accuracy: 0.7681 - val_loss: 0.7947
# Epoch 23/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.9262 - loss: 0.1985 - val_accuracy: 0.7603 - val_loss: 0.9600
# Epoch 24/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 23s 9ms/step - accuracy: 0.9251 - loss: 0.2019 - val_accuracy: 0.8062 - val_loss: 0.5926
# Epoch 25/25
# 2540/2540 ━━━━━━━━━━━━━━━━━━━━ 22s 9ms/step - accuracy: 0.9212 - loss: 0.2088 - val_accuracy: 0.7284 - val_loss: 1.4998

# %%
# from collections import Counter
# print("Train:", Counter(y_train))
# print("Val:", Counter(y_val))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                     │ (None, 64)                  │           1,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 29,349 (114.65 KB)
#  Trainable params: 9,697 (37.88 KB)
#  Non-trainable params: 256 (1.00 KB)
#  Optimizer params: 19,396 (75.77 KB)

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 847/847 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3399 - loss: 16.9893
# Test Accuracy: 0.7000

# %%
# Predict probabilities
y_pred_prob = model.predict(x_test)

# Convert to class labels (0 or 1)
y_pred = (y_pred_prob > 0.5).astype(int)

# Evaluation metrics
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 847/847 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# [[18959     0]
#  [ 8125     0]]
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82     18959
#            1       0.00      0.00      0.00      8125
#
#     accuracy                           0.70     27084
#    macro avg       0.35      0.50      0.41     27084
# weighted avg       0.49      0.70      0.58     27084
# C:\Users\2003n\anaconda3\envs\tf_env\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\2003n\anaconda3\envs\tf_env\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\2003n\anaconda3\envs\tf_env\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
import matplotlib.pyplot as plt

# Plot Accuracy
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## CNN

# %%
from tensorflow.keras.layers import Conv1D,Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix,classification_report

# %%
x_train.shape
# y_train.shape
# Out:
# (81252, 24)

# %%
x_train_cnn = x_train.to_numpy().reshape((x_train.shape[0], x_train.shape[1], 1))
# x_val_cnn   = x_val.to_numpy().reshape((x_val.shape[0], x_val.shape[1], 1))
x_test_cnn  = x_test.to_numpy().reshape((x_test.shape[0], x_test.shape[1], 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization

model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(24, 1)))
# model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.3))

model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.3))

# model.add(BatchNormalization())
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))
# Out:
# C:\Users\2003n\anaconda3\envs\tf_env\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 22, 64)              │             256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 11, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 11, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 9, 128)              │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 4, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 4, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_2 (Conv1D)                    │ (None, 2, 128)              │          49,280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_2 (MaxPooling1D)       │ (None, 1, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 1, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 82,561 (322.50 KB)
#  Trainable params: 82,561 (322.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',# also called objective/cost function
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
                    epochs=25,
                    batch_size=32,
                    validation_split=0.3,#validation_data=(X_val_cnn, Y_val)-> in case when we have x_val and y_val
                    verbose=1)#verbose is to check the values while the model is running. verbose=0,1,2 have different meaning
# Out:
# Epoch 1/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 35s 18ms/step - accuracy: 0.7893 - loss: 0.4281 - val_accuracy: 0.9729 - val_loss: 0.0792
# Epoch 2/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 30s 17ms/step - accuracy: 0.9166 - loss: 0.2236 - val_accuracy: 0.9751 - val_loss: 0.1023
# Epoch 3/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 30s 17ms/step - accuracy: 0.9277 - loss: 0.1921 - val_accuracy: 0.9774 - val_loss: 0.0669
# Epoch 4/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 27s 15ms/step - accuracy: 0.9322 - loss: 0.1799 - val_accuracy: 0.9773 - val_loss: 0.0601
# Epoch 5/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9337 - loss: 0.1759 - val_accuracy: 0.9759 - val_loss: 0.0604
# Epoch 6/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 30s 17ms/step - accuracy: 0.9355 - loss: 0.1744 - val_accuracy: 0.9753 - val_loss: 0.0754
# Epoch 7/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 28s 16ms/step - accuracy: 0.9350 - loss: 0.1758 - val_accuracy: 0.9800 - val_loss: 0.0564
# Epoch 8/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 28s 16ms/step - accuracy: 0.9354 - loss: 0.1692 - val_accuracy: 0.9767 - val_loss: 0.0570
# Epoch 9/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 31s 17ms/step - accuracy: 0.9347 - loss: 0.1752 - val_accuracy: 0.9792 - val_loss: 0.0539
# Epoch 10/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 31s 17ms/step - accuracy: 0.9382 - loss: 0.1650 - val_accuracy: 0.9838 - val_loss: 0.0451
# Epoch 11/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9364 - loss: 0.1686 - val_accuracy: 0.9766 - val_loss: 0.0603
# Epoch 12/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9366 - loss: 0.1666 - val_accuracy: 0.9799 - val_loss: 0.0469
# Epoch 13/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 32s 18ms/step - accuracy: 0.9382 - loss: 0.1618 - val_accuracy: 0.9830 - val_loss: 0.0440
# Epoch 14/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.9388 - loss: 0.1661 - val_accuracy: 0.9827 - val_loss: 0.0479
# Epoch 15/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - accuracy: 0.9389 - loss: 0.1637 - val_accuracy: 0.9794 - val_loss: 0.0605
# Epoch 16/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 38s 21ms/step - accuracy: 0.9387 - loss: 0.1628 - val_accuracy: 0.9860 - val_loss: 0.0523
# Epoch 17/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.9392 - loss: 0.1629 - val_accuracy: 0.9824 - val_loss: 0.0511
# Epoch 18/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 30s 17ms/step - accuracy: 0.9374 - loss: 0.1632 - val_accuracy: 0.9766 - val_loss: 0.0681
# Epoch 19/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.9388 - loss: 0.1628 - val_accuracy: 0.9855 - val_loss: 0.0456
# Epoch 20/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.9395 - loss: 0.1595 - val_accuracy: 0.9862 - val_loss: 0.0447
# Epoch 21/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - accuracy: 0.9393 - loss: 0.1586 - val_accuracy: 0.9861 - val_loss: 0.0411
# Epoch 22/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 34s 19ms/step - accuracy: 0.9365 - loss: 0.1641 - val_accuracy: 0.9836 - val_loss: 0.0487
# Epoch 23/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 36s 20ms/step - accuracy: 0.9389 - loss: 0.1601 - val_accuracy: 0.9816 - val_loss: 0.0652
# Epoch 24/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 35s 20ms/step - accuracy: 0.9386 - loss: 0.1600 - val_accuracy: 0.9838 - val_loss: 0.0556
# Epoch 25/25
# 1778/1778 ━━━━━━━━━━━━━━━━━━━━ 36s 20ms/step - accuracy: 0.9380 - loss: 0.1620 - val_accuracy: 0.9833 - val_loss: 0.0510

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 847/847 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.3399 - loss: 189.5913
# Test Accuracy: 0.7000

# %%
# Predict probabilities
y_pred_prob = model.predict(x_test)

# Convert to class labels (0 or 1)
y_pred = (y_pred_prob > 0.5).astype(int)

# Evaluation metrics
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 847/847 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step
# [[18959     0]
#  [ 8125     0]]
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82     18959
#            1       0.00      0.00      0.00      8125
#
#     accuracy                           0.70     27084
#    macro avg       0.35      0.50      0.41     27084
# weighted avg       0.49      0.70      0.58     27084
# C:\Users\2003n\anaconda3\envs\tf_env\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\2003n\anaconda3\envs\tf_env\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\2003n\anaconda3\envs\tf_env\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',# also called objective/cost function
              metrics=['accuracy'])

# %%
import matplotlib.pyplot as plt

# Plot Accuracy
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
 # return_sequences=True
model = Sequential()
model.add(LSTM(64, input_shape=(24, 1),return_sequences=True))
# model.add(BatchNormalization())
model.add(Dropout(0.3))


model.add(LSTM(32,return_sequences=False))
model.add(Dropout(0.3))


model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Binary classification
# Out:
# C:\Users\2003n\anaconda3\envs\tf_env\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 24, 64)              │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 24, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_16 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 32)                  │           1,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 30,401 (118.75 KB)
#  Trainable params: 30,401 (118.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',# also called objective/cost function
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
                    epochs=5,
                    batch_size=32,
                    validation_split=0.2,#validation_data=(X_val_cnn, Y_val)-> in case when we have x_val and y_val
                    verbose=1)#verbose is to check the values while the model is running. verbose=0,1,2 have different meaning
# Out:
# Epoch 1/5
# 2032/2032 ━━━━━━━━━━━━━━━━━━━━ 92s 42ms/step - accuracy: 0.9077 - loss: 0.2634 - val_accuracy: 0.9946 - val_loss: 0.0135
# Epoch 2/5
# 2032/2032 ━━━━━━━━━━━━━━━━━━━━ 83s 41ms/step - accuracy: 0.9325 - loss: 0.1748 - val_accuracy: 0.9979 - val_loss: 0.0048
# Epoch 3/5
# 2032/2032 ━━━━━━━━━━━━━━━━━━━━ 83s 41ms/step - accuracy: 0.9356 - loss: 0.1691 - val_accuracy: 0.9980 - val_loss: 0.0031
# Epoch 4/5
# 2032/2032 ━━━━━━━━━━━━━━━━━━━━ 80s 40ms/step - accuracy: 0.9376 - loss: 0.1629 - val_accuracy: 0.9956 - val_loss: 0.0098
# Epoch 5/5
# 2032/2032 ━━━━━━━━━━━━━━━━━━━━ 84s 41ms/step - accuracy: 0.9404 - loss: 0.1597 - val_accuracy: 0.9973 - val_loss: 0.0052

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 847/847 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step - accuracy: 0.3399 - loss: 6.7990
# Test Accuracy: 0.7000

# %%
# Predict probabilities
y_pred_prob = model.predict(x_test)

# Convert to class labels (0 or 1)
y_pred = (y_pred_prob > 0.5).astype(int)

# Evaluation metrics
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 847/847 ━━━━━━━━━━━━━━━━━━━━ 13s 15ms/step
# [[18959     0]
#  [ 8125     0]]
#               precision    recall  f1-score   support
#
#            0       0.70      1.00      0.82     18959
#            1       0.00      0.00      0.00      8125
#
#     accuracy                           0.70     27084
#    macro avg       0.35      0.50      0.41     27084
# weighted avg       0.49      0.70      0.58     27084
# C:\Users\2003n\anaconda3\envs\tf_env\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\2003n\anaconda3\envs\tf_env\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\2003n\anaconda3\envs\tf_env\lib\site-packages\sklearn\metrics\_classification.py:1706: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
import matplotlib.pyplot as plt

# Plot Accuracy
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
# plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
# plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## GRU

# %%
from tensorflow.keras.layers import GRU

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, BatchNormalization

model = Sequential()
model.add(GRU(64, input_shape=(24, 1), return_sequences=True))
model.add(Dropout(0.3))

model.add(GRU(32, return_sequences=False))
model.add(Dropout(0.3))

model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Binary classification

# %%
model.summary()

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='binary_crossentropy',# also called objective/cost function
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train,
                    epochs=5,
                    batch_size=32,
                    validation_split=0.2,#validation_data=(X_val_cnn, Y_val)-> in case when we have x_val and y_val
                    verbose=1)#verbose is to check the values while the model is running. verbose=0,1,2 have different meaning

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")

# %%
# Predict probabilities
y_pred_prob = model.predict(x_test)

# Convert to class labels (0 or 1)
y_pred = (y_pred_prob > 0.5).astype(int)

# Evaluation metrics
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %%
import matplotlib.pyplot as plt

# Plot Accuracy
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
# plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()
plt.grid(True)

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
# plt.plot(history.history['val_loss'], label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
accuracy=accuracy_score(y_test,y_pred)

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(confusion, annot=True, fmt='g', cmap='Blues', )
plt.xlabel('Predicted labels', fontsize=14, fontname='Times New Roman')
plt.ylabel('True labels', fontsize=14, fontname='Times New Roman')
plt.title('Confusion Matrix', fontsize=14, fontname='Times New Roman')
plt.show()

# %%
class_report=(classification_report(y_test, y_pred))
print(class_report)

# %%
fpr,tpr,roc=roc_curve(y_test,y_pred)
auc=roc_auc_score(y_test,y_pred)

# %%
plt.plot(fpr,tpr,color='darkorange',label=f'ROC curve(AUC={auc:.2f})')
plt.plot([0,1],[0,1],color='navy',linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Reciever Operting Charachterstics(ROC) curve')
plt.legend(loc='lower right')
plt.grid(True)
